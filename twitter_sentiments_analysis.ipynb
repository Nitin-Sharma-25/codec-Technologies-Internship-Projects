# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# Download the required VADER lexicon for sentiment analysis
nltk.download('vader_lexicon', quiet=True)
sia = SentimentIntensityAnalyzer()

print("--- SENTIMENT ANALYSER MODEL INITIALIZED ---\n")

# User Testing Interface
user_input = input("Enter the tweet or sentence to analyze: ")
score = sia.polarity_scores(user_input)['compound']

# Determine the sentiment class based on the compound score
if score >= 0.05:
    sentiment = "POSITIVE"
elif score <= -0.05:
    sentiment = "NEGATIVE"
else:
    sentiment = "NEUTRAL"

print(f"\nSentiment Analysis Result: {sentiment} (Compound Score: {score})")
# Out:
# --- SENTIMENT ANALYSER MODEL INITIALIZED ---
#
# Enter the tweet or sentence to analyze: i hate you bastard
#
# Sentiment Analysis Result: NEGATIVE (Compound Score: -0.802)
